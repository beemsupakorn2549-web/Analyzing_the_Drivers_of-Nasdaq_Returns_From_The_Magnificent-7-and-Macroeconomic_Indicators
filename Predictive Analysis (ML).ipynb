# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# ### Extract Data

# %%
df_returns = pd.read_csv(r'C:\Users\Windows 10\OneDrive\Desktop\Coding\Stat Comp\Project\Data\mag7_nasdaq_returns.csv')
df_returns.drop(columns=['Unnamed: 0'], inplace=True)
df_returns['Date_Return'] = pd.to_datetime(df_returns['Date_Return'])
df_returns = df_returns.set_index('Date_Return')
df_returns.head()
# Out:
#              AAPL_Return  AMZN_Return  WTI_Crude_Oil_Return  \
# Date_Return
# 2021-01-05      0.012364     0.010004              0.048509
# 2021-01-06     -0.033662    -0.024897              0.014020
# 2021-01-07      0.034123     0.007577              0.003950
# 2021-01-08      0.008631     0.006496              0.027740
# 2021-01-11     -0.023249    -0.021519              0.000191
#
#              Dollar_Index_Return  COMEX_Gold_Return  GOOGL_Return  \
# Date_Return
# 2021-01-05             -0.004895           0.004114      0.008064
# 2021-01-06              0.001006          -0.023455     -0.009868
# 2021-01-07              0.003351           0.002832      0.029869
# 2021-01-08              0.003006          -0.040893      0.013239
# 2021-01-11              0.004883           0.008451     -0.023106
#
#              META_Return  MSFT_Return  NVDA_Return  Treasury_Inflation_Return  \
# Date_Return
# 2021-01-05      0.007548     0.000965     0.022210                  -0.000313
# 2021-01-06     -0.028269    -0.025929    -0.058953                  -0.002975
# 2021-01-07      0.020622     0.028457     0.057830                  -0.000628
# 2021-01-08     -0.004354     0.006093    -0.005040                  -0.003928
# 2021-01-11     -0.040102    -0.009699     0.025967                  -0.002130
#
#              TSLA_Return  Nasdaq_Return  VIX_Fear_Index_Return
# Date_Return
# 2021-01-05      0.007317       0.009490              -0.060437
# 2021-01-06      0.028390      -0.006098              -0.010655
# 2021-01-07      0.079447       0.025641              -0.107698
# 2021-01-08      0.078403       0.010293              -0.036209
# 2021-01-11     -0.078214      -0.012540               0.116883

# %% [markdown]
# ### Train Data

# %%
# 'Date' is already the index of df_returns, so drop only the target column
X = df_returns.drop(columns=['Nasdaq_Return'])
y = df_returns['Nasdaq_Return']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ### Modeling

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Test & Predict

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %% [markdown]
# ### Evaluation Metrics

# %%
r2 = r2_score(y_test, y_pred_test)
mae = mean_absolute_error(y_test, y_pred_test)
mse = mean_squared_error(y_test, y_pred_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
mape = np.mean(np.abs((y_test - y_pred_test) / y_test)) * 100
wape = np.sum(np.abs(y_test - y_pred_test)) / np.sum(np.abs(y_test)) * 100

print("-" * 30)
print(f"Result of MLR")
print("-" * 30)
print(f"MAE:  {mae:.5f}")
print(f"MSE:  {mse:.5f}")
print(f"RMSE: {rmse:.5f}")
print(f"MAPE: {mape:.2f}%")
print(f"WAPE: {wape:.2f}%")
print(f"R-squared:  {r2:.4f}")
# Out:
# ------------------------------
# Result of MLR
# ------------------------------
# MAE:  0.00254
# MSE:  0.00001
# RMSE: 0.00329
# MAPE: inf%
# WAPE: 26.00%
# R-squared:  0.9533

# %%
# Create a DataFrame to analyze errors
df = pd.DataFrame({'Actual': y_test, 'Forecast': y_pred_test})
df['Absolute_Error'] = abs(df['Actual'] - df['Forecast'])
df['APE'] = (df['Absolute_Error'] / df['Actual']) * 100

# Sort by APE to find the top 10 instances with the highest percentage error
print(df.sort_values(by='APE', ascending=False).head(10))
# Out:
#                Actual  Forecast  Absolute_Error          APE
# Date_Return
# 2025-01-09   0.000000 -0.000336        0.000336          inf
# 2025-05-26   0.000000  0.000085        0.000085          inf
# 2025-07-04   0.000000 -0.000219        0.000219          inf
# 2025-05-09   0.000043  0.003335        0.003291  7571.854110
# 2025-09-10   0.000300 -0.005964        0.006264  2085.996238
# 2025-05-19   0.000227 -0.001991        0.002218   976.982913
# 2025-07-18   0.000479  0.004167        0.003688   770.297917
# 2025-02-18   0.000724 -0.004558        0.005281   729.922027
# 2025-08-18   0.000314 -0.001251        0.001565   498.521008
# 2025-04-07   0.000992 -0.002332        0.003324   334.975816

# %% [markdown]
# ### Regression Line Prediction

# %%
# Combine actual and predicted test values into a DataFrame for easier plotting
df_regression = pd.DataFrame({
    'Actual Nasdaq Return': y_test,
    'Predicted Nasdaq Return': y_pred_test
}).dropna()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='Actual Nasdaq Return', y='Predicted Nasdaq Return', data=df_regression, alpha=0.6)

# Add a perfect prediction line (y=x)
min_val = min(df_regression['Actual Nasdaq Return'].min(), df_regression['Predicted Nasdaq Return'].min())
max_val = max(df_regression['Actual Nasdaq Return'].max(), df_regression['Predicted Nasdaq Return'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Prediction')

plt.title('MLR Regression Plot: Actual vs Predicted Nasdaq Returns (Test Set)')
plt.xlabel('Actual Nasdaq Return')
plt.ylabel('Predicted Nasdaq Return')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Actual vs Predicted Nasdaq Returns by time

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label='Actual Nasdaq Return', color='blue', alpha=0.6)
plt.plot(y_test.index, y_pred_test, label='Predicted Return', color='red', linestyle='--', alpha=0.8)
plt.title('Actual vs Predicted Nasdaq Returns (Test Set)')
plt.legend()
plt.grid(True, alpha=0.4)

# %% [markdown]
# ### Distribution of Actual vs. Predicted Nasdaq Returns

# %%
plt.figure(figsize=(12,6))
sns.histplot(y_test, kde=True, color='blue', label='Actual Nasdaq Return', alpha=0.6, stat='density', linewidth=0)
sns.histplot(y_pred_test, kde=True, color='red', label='Predicted Nasdaq Return', alpha=0.6, stat='density', linewidth=0)
plt.title('Distribution of Actual vs. Predicted Nasdaq Returns (Test Set)')
plt.xlabel('Nasdaq Return')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=00.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Coefficients of Feature Impact

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})
# Sort coefficients from lowest to highest (so highest positive values appear at top)
coef_df = coef_df.sort_values(by='Coefficient', ascending=True)

print("\nCoefficients of each feature in ascending order:")
print(coef_df)
# Out:
# Coefficients of each feature in ascending order:
#                       Feature  Coefficient
# 3         Dollar_Index_Return    -0.144834
# 11      VIX_Fear_Index_Return    -0.024247
# 4           COMEX_Gold_Return    -0.010979
# 2        WTI_Crude_Oil_Return     0.005021
# 9   Treasury_Inflation_Return     0.043361
# 6                 META_Return     0.052844
# 10                TSLA_Return     0.057108
# 5                GOOGL_Return     0.072733
# 8                 NVDA_Return     0.097482
# 1                 AMZN_Return     0.102348
# 7                 MSFT_Return     0.130536
# 0                 AAPL_Return     0.166259

# %%
import matplotlib.colors as mcolors

plt.figure(figsize=(10, 6))

# Create a colormap from red (negative) to green (positive)
cmap = plt.cm.RdYlGn
norm = mcolors.Normalize(vmin=coef_df['Coefficient'].min(), vmax=coef_df['Coefficient'].max())
colors = [cmap(norm(val)) for val in coef_df['Coefficient']]

# Create horizontal bar chart with color palette
plt.barh(coef_df['Feature'], coef_df['Coefficient'], color=colors)
plt.xlabel('Coefficient')
plt.title('Feature Impact on Nasdaq (MLR Coefficients)')
plt.axvline(0, color='black', linestyle='--', linewidth=0.8)

plt.tight_layout()
plt.show()
