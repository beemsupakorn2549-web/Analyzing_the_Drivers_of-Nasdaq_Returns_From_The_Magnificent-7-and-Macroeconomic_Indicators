# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from scipy.stats import spearmanr
from scipy.stats import pearsonr
# Out:
# c:\Users\Windows 10\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Extract Data

# %%
df_returns = pd.read_csv('C:\\Users\\Windows 10\\OneDrive\\Desktop\\Coding\\Stat Comp\\Project\\Data\\mag7_nasdaq_returns.csv')
df_returns.drop(columns=['Unnamed: 0'], inplace=True)
df_returns.head()
# Out:
#    AAPL_Return  AMZN_Return  WTI_Crude_Oil_Return  Dollar_Index_Return  \
# 0     0.012364     0.010004              0.048509            -0.004895
# 1    -0.033662    -0.024897              0.014020             0.001006
# 2     0.034123     0.007577              0.003950             0.003351
# 3     0.008631     0.006496              0.027740             0.003006
# 4    -0.023249    -0.021519              0.000191             0.004883
#
#    COMEX_Gold_Return  GOOGL_Return  META_Return  MSFT_Return  NVDA_Return  \
# 0           0.004114      0.008064     0.007548     0.000965     0.022210
# 1          -0.023455     -0.009868    -0.028269    -0.025929    -0.058953
# 2           0.002832      0.029869     0.020622     0.028457     0.057830
# 3          -0.040893      0.013239    -0.004354     0.006093    -0.005040
# 4           0.008451     -0.023106    -0.040102    -0.009699     0.025967
#
#    Treasury_Inflation_Return  TSLA_Return  Nasdaq_Return  \
# 0                  -0.000313     0.007317       0.009490
# 1                  -0.002975     0.028390      -0.006098
# 2                  -0.000628     0.079447       0.025641
# 3                  -0.003928     0.078403       0.010293
# 4                  -0.002130    -0.078214      -0.012540
#
#    VIX_Fear_Index_Return Date_Return
# 0              -0.060437  2021-01-05
# 1              -0.010655  2021-01-06
# 2              -0.107698  2021-01-07
# 3              -0.036209  2021-01-08
# 4               0.116883  2021-01-11

# %% [markdown]
# ### Peason Correlation Measure

# %%
# Prepare a sorted DataFrame of correlations with Nasdaq for visualization
nasdaq_corr_sorted = (
    df_returns.drop(columns=['Date_Return'], errors='ignore')
    .corr()[['Nasdaq_Return']]
    .drop('Nasdaq_Return')
    .reset_index()
    .rename(columns={'index': 'Feature', 'Nasdaq_Return': 'Correlation'})
    .sort_values(by='Correlation', ascending=False)
)

# %%
# 2. Calculate Pearson correlation and p-value for each feature against Nasdaq, and store results in a list of dictionaries
results = []

cols_to_test = df_returns.drop(columns=['Nasdaq_Return', 'Date_Return'], errors='ignore').columns
for col in cols_to_test:
    corr, p_val = pearsonr(df_returns[col], df_returns['Nasdaq_Return'])
    results.append({
        'Asset': col, 
        'Correlation': corr, 
        'P-value': p_val,
        'Linearity (P < 0.05)': 'Pass' if p_val < 0.05 else 'Fail'
    })

# %%
# Create a DataFrame to display the results
hypo_test_df = pd.DataFrame(results)
display(hypo_test_df)
# Out:
#                         Asset  Correlation        P-value Linearity (P < 0.05)
# 0                 AAPL_Return     0.778753  3.320625e-256                 Pass
# 1                 AMZN_Return     0.776415  1.065891e-253                 Pass
# 2        WTI_Crude_Oil_Return     0.101205   3.276756e-04                 Pass
# 3         Dollar_Index_Return    -0.208833   7.645277e-14                 Pass
# 4           COMEX_Gold_Return     0.062106   2.773827e-02                 Pass
# 5                GOOGL_Return     0.741355  1.924281e-219                 Pass
# 6                 META_Return     0.681363  3.762789e-172                 Pass
# 7                 MSFT_Return     0.805227  6.712617e-287                 Pass
# 8                 NVDA_Return     0.787303  1.233934e-265                 Pass
# 9   Treasury_Inflation_Return     0.173496   6.032316e-10                 Pass
# 10                TSLA_Return     0.646966  7.644079e-150                 Pass
# 11      VIX_Fear_Index_Return    -0.704955  2.560301e-189                 Pass

# %%
# Visualize the correlations with a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Correlation', y='Feature', data=nasdaq_corr_sorted, legend=False, palette='coolwarm')
plt.title('Pearson Correlation of Features with Nasdaq')
plt.xlabel('Correlation Coefficient (r)')
plt.ylabel('Features')
plt.axvline(x=0, color='black', linestyle='--')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Temp\ipykernel_16216\755547570.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Correlation', y='Feature', data=nasdaq_corr_sorted, legend=False, palette='coolwarm')

# %% [markdown]
# ### Scatter Visualization

# %%
# Get all columns except Date
stocks = df_returns.drop(columns=['Date_Return','Nasdaq_Return']).columns

# Create subplots - 3 rows x 4 columns
n_cols = 4
n_rows = (len(stocks) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 12))
axes = axes.flatten()  # Flatten to 1D array for easier iteration

for idx, stock in enumerate(stocks):
    ax = axes[idx]
    ax.scatter(df_returns[stock], df_returns['Nasdaq_Return'], color='#007acc', alpha=0.6)
    ax.set_title(f'{stock} Returns vs Nasdaq Returns', fontsize=11, fontweight='bold')
    ax.set_xlabel(f'{stock} Returns', fontsize=9)
    ax.set_ylabel('Nasdaq Returns', fontsize=9)
    ax.grid(True, linestyle='--', alpha=0.6)
    ax.tick_params(axis='x', rotation=45)

# Hide any unused subplots
for idx in range(len(stocks), len(axes)):
    axes[idx].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(8, 6))
correlation_matrix = df_returns.drop(columns=['Date_Return']).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Return Heatmap')
plt.show()
